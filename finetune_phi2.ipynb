# %% [markdown]
# ## **Engineering with Generative AI **

# %% [markdown]
# Downloading a required libraries :

# %%
# !pip install -q transformers>=4.32.0 datasets evaluate                                                # Comes from HuggingFace
# !pip install -q auto-gptq --extra-index-url https://huggingface.github.io/autogptq-index/whl/cu118/   # Use cu117 if on CUDA 11.7                                                                              # For GPTQ Optimization
# !pip install -q -U bitsandbytes                                                                       # For quantization
# !pip install -q -U peft                                                                               # Parameter-efficient Fine-tuning
# !pip install -q -U accelerate                                                                         # Loading models across GPUs/CPU/disk
# !pip install -q trl                                                                                   # For supervised fine-tuning for LLMs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 88.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 99.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.1/342.1 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 8.0 MB/s eta 0:00:00

# %% [markdown]
# Mounting Google Drive :

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Basic imports
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %% [markdown]
# **Bitsandbytes configuration** : Uses Quantization config to bnb config. this is QLORA -> Quanitzing the pretrained wieights of model to 4-bit & keeping them fixed during FT

# %%
from transformers import BitsAndBytesConfig

# 1. Setup the quantization configuarion
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,                     # Q = 4 bits
    bnb_4bit_use_double_quant=True,        # double quantization, quantizing the quantization constants for saving an additional 0.4 bits per parameter
    bnb_4bit_quant_type="nf4",             # 4-bit NormalFloat Quantization (optimal for normal weights; enforces w ∈ [-1,1])
    bnb_4bit_compute_dtype=torch.bfloat16  # Dequantize to 16-bits before computations (as in the paper)
)

# %% [markdown]
# **Loading the pretrained model :**

# %%
model_name_or_path = "microsoft/phi-2"
model = AutoModelForCausalLM.from_pretrained(model_name_or_path, trust_remote_code=True, quantization_config=bnb_config, device_map="auto")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/35.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/564M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %% [markdown]
# **Tokenization** :

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]

# %%
from datasets import load_dataset

# %% [markdown]
# Loading Dataset : (MBPP)

# %%
dataset_name = "mbpp"
dataset = load_dataset(dataset_name)
# Out:
# README.md:   0%|          | 0.00/9.06k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/87.2k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/116k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# prompt-00000-of-00001.parquet:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/374 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/90 [00:00<?, ? examples/s]
# Generating prompt split:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
dataset['test'][0]
# Out:
# {'task_id': 11,
#  'text': 'Write a python function to remove first and last occurrence of a given character from the string.',
#  'code': 'def remove_Occ(s,ch): \r\n    for i in range(len(s)): \r\n        if (s[i] == ch): \r\n            s = s[0 : i] + s[i + 1:] \r\n            break\r\n    for i in range(len(s) - 1,-1,-1):  \r\n        if (s[i] == ch): \r\n            s = s[0 : i] + s[i + 1:] \r\n            break\r\n    return s ',
#  'test_list': ['assert remove_Occ("hello","l") == "heo"',
#   'assert remove_Occ("abcda","a") == "bcd"',
#   'assert remove_Occ("PHP","P") == "H"'],
#  'test_setup_code': '',
#  'challenge_test_list': ['assert remove_Occ("hellolloll","l") == "helollol"',
#   'assert remove_Occ("","l") == ""']}

# %% [markdown]
# **Method for Saving Dataset splits in JSON format.**

# %%
import json
import os

def save_model_data(dataset, model_name, datasetType):
    if datasetType == "test":
        dataset_list = list(map(lambda item: {'text': item['text'], 'code': item['code']}, dataset))
    else:
        dataset_list = [{'prompt': item} for item in dataset['prompt']]

    # Define directory & file name
    directory = "/content/drive/MyDrive/ColabResults/"
    file_name = f"{directory}{model_name}_{datasetType}_data.json"

    # ✅ Create the directory if it does not exist
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Created directory: {directory}")

    # ✅ Overwrite existing file
    if os.path.exists(file_name):
        print(f"File '{file_name}' already exists. Overriding its content.")

    # ✅ Save dataset as JSON
    with open(file_name, 'w') as json_file:
        json.dump(dataset_list, json_file, indent=4)

    print(f"Dataset saved to '{file_name}'")

# %% [markdown]
# Loading Test Split from Dataset

# %%
test_dataset = dataset["test"].shuffle(seed=42).select([i for i in range(130)])

# %%
test_dataset
# Out:
# Dataset({
#     features: ['task_id', 'text', 'code', 'test_list', 'test_setup_code', 'challenge_test_list'],
#     num_rows: 130
# })

# %% [markdown]
# Calling save_model_data method to save test split in JSON format

# %%
model_name = 'Model'
datasetType = "test"
save_model_data(test_dataset,model_name,datasetType)
# Out:
# Created directory: /content/drive/MyDrive/ColabResults/
# Dataset saved to '/content/drive/MyDrive/ColabResults/Model_test_data.json'

# %%
import re
def clean_text(text):
    # Remove special characters and extra spaces
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    text = re.sub(r'\t+', ' ', text)
    text = re.sub(r'\n+', ' ', text)
    text = re.sub(r'\r+', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %%
def create_prompt_formats(data_point):

    data_point['text'] = clean_text(data_point['text'])
    data_point['code'] = clean_text(data_point['code'])

    full_prompt = f""" Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.
    ### Instruction: {data_point['text'].strip()}
    ### Response:
    {data_point['code'].strip()}
    """.strip()
    return full_prompt;

# %%
def generate(model,instruction, maxlen=128):

    instruction = clean_text(instruction)
    full_prompt = f"""
        Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.
        ### Instruction: {instruction.strip()}
        ### Response:
        """
    device = model.device  # Automatically get the model's device
    inputs = tokenizer(full_prompt, return_tensors="pt").to(device)


    with torch.no_grad():
        generation_output = model.generate(
            **inputs,
            max_new_tokens=maxlen,
            )

        result = tokenizer.decode(generation_output[0], skip_special_tokens=True)
        if result:
            output = result.strip()

            # Using regular expression to extract only the response section
            response_section = re.search(r'### Response:\n(.+?)(?=# Test Cases\n|\Z)', output, re.DOTALL)


            if response_section:
                model_response = response_section.group(1).strip()
                return model_response;
            else:
                print("Response section not found.")
        else:
            print("Failed to generate the response.")

    return ""

# %% [markdown]
# **Test the model with Zero Shot Inferencing - Model A**

# %%
# %%time

model_response = ''
text_input = test_dataset[2]["text"]

instruction = text_input
print("instruction ", instruction)


result = generate(model, instruction);
print("result",result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# instruction  Write a python function to find the first natural number whose factorial is divisible by x.
# result def first_factorial_divisible_by_x(x):
#             n = 1
#             while True:
#                 if math.factorial(n) % x == 0:
#                     return n
#                 n += 1
#
#         # Test cases
#         assert first_factorial_divisible_by_x(2) == 1
#         assert first_factorial_divisible_by_x(3) == 2
#         assert first_factorial_divisible_by_x(4) == 3
#         assert first_factorial_divisible_by_x(
# CPU times: user 10.7 s, sys: 353 ms, total: 11.1 s
# Wall time: 15 s

# %% [markdown]
# **Installing Codebleu Library**

# %%
# !pip install codebleu
# Out:
# Collecting codebleu
#   Downloading codebleu-0.7.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting tree-sitter<0.23.0,>=0.22.0 (from codebleu)
#   Downloading tree_sitter-0.22.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools>=61.0.0 in /usr/local/lib/python3.11/dist-packages (from codebleu) (75.1.0)
# Downloading codebleu-0.7.0-py3-none-any.whl (31 kB)
# Downloading tree_sitter-0.22.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.2/544.2 kB 17.3 MB/s eta 0:00:00
# Installing collected packages: tree-sitter, codebleu
# Successfully installed codebleu-0.7.0 tree-sitter-0.22.3

# %% [markdown]
# Method for evaluating Model Code Response and Ground Truth Code.

# %%
from codebleu import calc_codebleu

def codebleu_evaluation(original_output,model_response):
    ref = original_output
    pred = model_response
    res = calc_codebleu([ref], [pred], "python")
    if(res):
        return res['codebleu'];

# %% [markdown]
# This "final_Evaluation_results" used for storing Codebleu Accuracy Values

# %%
final_Evaluation_results = {}

# %% [markdown]
# **Method to Calculate Model's Accuracy against respective dataset :**

# %%
def calculate_model_accuracy(model,dataset):
   evaluation_readings = []
   model_accuracy = 0;

   with torch.no_grad():
      for data_point in dataset:
         instruction =  data_point["text"];
         model_response  = generate(model,instruction);

         if model_response  :
            evaluation_value = codebleu_evaluation(data_point["code"],model_response)
            evaluation_readings.append(evaluation_value)


   if(evaluation_readings):
      totalNoOfReadings = len(evaluation_readings);
      sum = 0;
      for reading in evaluation_readings:
         sum += reading;

      model_accuracy = sum/totalNoOfReadings;
   return {"accuracy" : model_accuracy, "evaluation_readings":evaluation_readings};

# %% [markdown]
# **Evaluate the Model A**

# %% [markdown]
# Calculated & Added ModelA accuracy into "final_Evaluation_results"

# %%
# !pip uninstall -y tree-sitter-python tree-sitter
# !pip install tree-sitter tree-sitter-languages
# Out:
# WARNING: Skipping tree-sitter-python as it is not installed.
# Found existing installation: tree-sitter 0.24.0
# Uninstalling tree-sitter-0.24.0:
#   Successfully uninstalled tree-sitter-0.24.0
# Collecting tree-sitter
#   Using cached tree_sitter-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: tree-sitter-languages in /usr/local/lib/python3.11/dist-packages (1.10.2)
# Using cached tree_sitter-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (575 kB)
# Installing collected packages: tree-sitter
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# codebleu 0.7.0 requires tree-sitter<0.23.0,>=0.22.0, but you have tree-sitter 0.24.0 which is incompatible.
# Successfully installed tree-sitter-0.24.0

# %%
def evaluate_simple(model_response, expected_output):
    return int(expected_output.strip() in model_response.strip())

# Example Usage
instruction = test_dataset[2]["text"]
expected_code = test_dataset[2]["code"]
generated_code = generate(model, instruction)

score = evaluate_simple(generated_code, expected_code)
print("Pass" if score else "Fail")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Fail

# %% [markdown]
# **Method for Adding Model's Accuracy permanentaly into the CSV file.**

# %%
import os
import pandas as pd

def add_Evaluation_Result(data_object):
    file_path = '/content/drive/MyDrive/ColabResults/final_evaluation_results.csv'

    # ✅ Check if the data_object is empty
    if not data_object:
        print("Error: No evaluation results found. Ensure evaluation is performed before saving.")
        return

    modelName = list(data_object.keys())[0]  # Extract model name
    accuracy = data_object[modelName].get('accuracy', None)  # Extract accuracy safely

    if accuracy is None:
        print(f"Error: Accuracy not found for model {modelName}.")
        return

    file_exists = os.path.exists(file_path)

    if file_exists:
        try:
            existing_df = pd.read_csv(file_path)
        except pd.errors.EmptyDataError:
            existing_df = pd.DataFrame(columns=['Model', 'Accuracy'])
    else:
        existing_df = pd.DataFrame(columns=['Model', 'Accuracy'])

    new_df = pd.DataFrame({'Model': [modelName], 'Accuracy': [accuracy]})
    combined_df = pd.concat([existing_df, new_df], ignore_index=True)

    combined_df.to_csv(file_path, index=False)
    print(f"✅ Data for {modelName} with accuracy {accuracy} has been saved in final_evaluation_results.csv.")

# %% [markdown]
# Added ModelA accuracy into CSV file.

# %%
add_Evaluation_Result(final_Evaluation_results)
# Out:
# Error: No evaluation results found. Ensure evaluation is performed before saving.

# %% [markdown]
# **Preprocessing of Dataset :**

# %%
def convert_to_instruction_format(data_point):
    return {"prompt": create_prompt_formats(data_point)}

# %%
def process_dataset(data):
    dataset =  data.map(convert_to_instruction_format).remove_columns(['task_id', 'text', 'code', 'test_list', 'test_setup_code', 'challenge_test_list'])
    return dataset;

# %% [markdown]
# Loading Train Data :

# %%
train_data = process_dataset(dataset["train"].shuffle(seed=42).select([i for i in range(360)]))
# Out:
# Map:   0%|          | 0/360 [00:00<?, ? examples/s]

# %% [markdown]
# Save Train Data split into JSON file

# %%
model_name = 'ModelB'
datasetType = "train"
save_model_data(train_data,model_name,datasetType)
# Out:
# Dataset saved to '/content/drive/MyDrive/ColabResults/ModelB_train_data.json'

# %% [markdown]
# Loading Validation Data :

# %%
validation_data  = process_dataset(dataset["validation"].shuffle(seed=42).select([i for i in range(60)]))
# Out:
# Map:   0%|          | 0/60 [00:00<?, ? examples/s]

# %% [markdown]
# Save Validation Data split into JSON file.

# %%
model_name = 'ModelB'
datasetType = "validation"
save_model_data(validation_data,model_name,datasetType)
# Out:
# Dataset saved to '/content/drive/MyDrive/ColabResults/ModelB_validation_data.json'

# %% [markdown]
# Train Data Sample after preprocessing :

# %%
train_data["prompt"]
# Out:
# ['Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if the given tuple has any none value or not.\n    ### Response:\n    def check_none(test_tup): res = any(map(lambda ele: ele is None, test_tup)) return (res)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to convert camel case string to snake case string.\n    ### Response:\n    def camel_to_snake(text): import re str1 = re.sub('(.)([A-Z][a-z]+)', r'\\1_\\2', text) return re.sub('([a-z0-9])([A-Z])', r'\\1_\\2', str1).lower()",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find if there is a triplet in the array whose sum is equal to a given value.\n    ### Response:\n    def find_triplet_array(A, arr_size, sum): for i in range( 0, arr_size-2): for j in range(i + 1, arr_size-1): for k in range(j + 1, arr_size): if A[i] + A[j] + A[k] == sum: return A[i],A[j],A[k] return True return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to calculate the product of all the numbers of a given tuple.\n    ### Response:\n    def mutiple_tuple(nums): temp = list(nums) product = 1 for x in temp: product *= x return product',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to add a dictionary to the tuple.\n    ### Response:\n    def add_dict_to_tuple(test_tup, test_dict): test_tup = list(test_tup) test_tup.append(test_dict) test_tup = tuple(test_tup) return (test_tup)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to toggle bits of the number except the first and the last bit.\n    ### Response:\n    def set_middle_bits(n): n |= n >> 1; n |= n >> 2; n |= n >> 4; n |= n >> 8; n |= n >> 16; return (n >> 1) ^ 1 def toggle_middle_bits(n): if (n == 1): return 1 return n ^ set_middle_bits(n)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to count the number of pairs whose sum is equal to sum .\n    ### Response:\n    def get_Pairs_Count(arr,n,sum): count = 0 for i in range(0,n): for j in range(i + 1,n): if arr[i] + arr[j] == sum: count += 1 return count',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find maximum run of uppercase characters in the given string.\n    ### Response:\n    def max_run_uppercase(test_str): cnt = 0 res = 0 for idx in range(0, len(test_str)): if test_str[idx].isupper(): cnt += 1 else: res = cnt cnt = 0 if test_str[len(test_str) - 1].isupper(): res = cnt return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to iterate over all pairs of consecutive items in a given list.\n    ### Response:\n    def pair_wise(l1): temp = [] for i in range(len(l1) - 1): current_element, next_element = l1[i], l1[i + 1] x = (current_element, next_element) temp.append(x) return temp',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if one tuple is a subset of another tuple.\n    ### Response:\n    def check_subset(test_tup1, test_tup2): res = set(test_tup2).issubset(test_tup1) return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to print duplicants from a list of integers.\n    ### Response:\n    def Repeat(x): _size = len(x) repeated = [] for i in range(_size): k = i + 1 for j in range(k, _size): if x[i] == x[j] and x[i] not in repeated: repeated.append(x[i]) return repeated',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to flatten the given tuple matrix into the tuple list with each tuple representing each column.\n    ### Response:\n    def matrix_to_list(test_list): temp = [ele for sub in test_list for ele in sub] res = list(zip(*temp)) return (str(res))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find numbers divisible by m and n from a list of numbers using lambda function.\n    ### Response:\n    def div_of_nums(nums,m,n): result = list(filter(lambda x: (x % m == 0 and x % n == 0), nums)) return result',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to left rotate the string.\n    ### Response:\n    def left_rotate(s,d): tmp = s[d : ] + s[0 : d] return tmp',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the perimeter of a rectangle.\n    ### Response:\n    def rectangle_perimeter(l,b): perimeter=2*(l+b) return perimeter',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to put spaces between words starting with capital letters in a given string by using regex.\n    ### Response:\n    import re def capital_words_spaces(str1): return re.sub(r"(\\w)([A-Z])", r"\\1 \\2", str1)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the index of the first occurrence of a given number in a sorted array.\n    ### Response:\n    def find_first_occurrence(A, x): (left, right) = (0, len(A) - 1) result = -1 while left <= right: mid = (left + right) // 2 if x == A[mid]: result = mid right = mid - 1 elif x < A[mid]: right = mid - 1 else: left = mid + 1 return result',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function that matches a string that has an 'a' followed by anything, ending in 'b'.\n    ### Response:\n    import re def text_starta_endb(text): patterns = 'a.*?b$' if re.search(patterns, text): return 'Found a match!' else: return('Not matched!')",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the sum of squares of binomial co-efficients.\n    ### Response:\n    def factorial(start,end): res = 1 for i in range(start,end + 1): res *= i return res def sum_of_square(n): return int(factorial(n + 1, 2 * n) /factorial(1, n))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find minimum possible value for the given periodic function.\n    ### Response:\n    def floor_Min(A,B,N): x = max(B - 1,N) return (A*x) // B',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to count repeated items of a tuple.\n    ### Response:\n    def count_tuplex(tuplex,value): count = tuplex.count(value) return count',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to get a lucid number smaller than or equal to n.\n    ### Response:\n    def get_ludic(n): ludics = [] for i in range(1, n + 1): ludics.append(i) index = 1 while(index != len(ludics)): first_ludic = ludics[index] remove_index = index + first_ludic while(remove_index < len(ludics)): ludics.remove(ludics[remove_index]) remove_index = remove_index + first_ludic - 1 index += 1 return ludics',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find sum of inverse of divisors.\n    ### Response:\n    def Sum_of_Inverse_Divisors(N,Sum): ans = float(Sum)*1.0 /float(N); return round(ans,2);',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to list out the list of given strings individually using map function.\n    ### Response:\n    def listify_list(list1): result = list(map(list,list1)) return result',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find number of even elements in the given list using lambda function.\n    ### Response:\n    def count_even(array_nums): count_even = len(list(filter(lambda x: (x%2 == 0) , array_nums))) return count_even',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to count the most common character in a given string.\n    ### Response:\n    from collections import Counter def max_char(str1): temp = Counter(str1) max_char = max(temp, key = temp.get) return max_char',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to sort a list in a dictionary.\n    ### Response:\n    def sorted_dict(dict1): sorted_dict = {x: sorted(y) for x, y in dict1.items()} return sorted_dict',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to count number of cubes of size k in a cube of size n.\n    ### Response:\n    def No_of_cubes(N,K): No = 0 No = (N - K + 1) No = pow(No, 3) return No',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the longest chain which can be formed from the given set of pairs.\n    ### Response:\n    class Pair(object): def __init__(self, a, b): self.a = a self.b = b def max_chain_length(arr, n): max = 0 mcl = [1 for i in range(n)] for i in range(1, n): for j in range(0, i): if (arr[i].a > arr[j].b and mcl[i] < mcl[j] + 1): mcl[i] = mcl[j] + 1 for i in range(n): if (max < mcl[i]): max = mcl[i] return max',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the fixed point in the given array.\n    ### Response:\n    def find_fixed_point(arr, n): for i in range(n): if arr[i] is i: return i return -1',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find out the second most repeated (or frequent) string in the given sequence.\n    ### Response:\n    from collections import Counter def second_frequent(input): dict = Counter(input) value = sorted(dict.values(), reverse=True) second_large = value[1] for (key, val) in dict.items(): if val == second_large: return (key)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to remove all the words with k length in the given string.\n    ### Response:\n    def remove_length(test_str, K): temp = test_str.split() res = [ele for ele in temp if len(ele) != K] res = ' '.join(res) return (res)",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the slope of a line.\n    ### Response:\n    def slope(x1,y1,x2,y2): return (float)(y2-y1)/(x2-x1)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the minimun number of subsets with distinct elements.\n    ### Response:\n    def subset(ar, n): res = 0 ar.sort() for i in range(0, n) : count = 1 for i in range(n - 1): if ar[i] == ar[i + 1]: count+=1 else: break res = max(res, count) return res',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the index of an extra element present in one sorted array.\n    ### Response:\n    def find_Extra(arr1,arr2,n) : for i in range(0, n) : if (arr1[i] != arr2[i]) : return i return n',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to sort the tuples alphabetically by the first item of each tuple.\n    ### Response:\n    def sort_tuple(tup): n = len(tup) for i in range(n): for j in range(n-i-1): if tup[j][0] > tup[j + 1][0]: tup[j], tup[j + 1] = tup[j + 1], tup[j] return tup',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the perimeter of a rombus.\n    ### Response:\n    def rombus_perimeter(a): perimeter=4*a return perimeter',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to count the total unset bits from 1 to n.\n    ### Response:\n    def count_Unset_Bits(n) : cnt = 0; for i in range(1,n + 1) : temp = i; while (temp) : if (temp % 2 == 0) : cnt += 1; temp = temp // 2; return cnt;',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check whether the given month name contains 31 days or not.\n    ### Response:\n    def check_monthnumb(monthname2): if(monthname2=="January" or monthname2=="March"or monthname2=="May" or monthname2=="July" or monthname2=="Augest" or monthname2=="October" or monthname2=="December"): return True else: return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find maximum of two numbers.\n    ### Response:\n    def max_of_two( x, y ): if x > y: return x return y',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether all the characters are same or not.\n    ### Response:\n    def all_Characters_Same(s) : n = len(s) for i in range(1,n) : if s[i] != s[0] : return False return True',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to reverse each list in a given list of lists.\n    ### Response:\n    def reverse_list_lists(lists): for l in lists: l.sort(reverse = True) return lists',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to split a string at uppercase letters.\n    ### Response:\n    import re def split_upperstring(text): return (re.findall('[A-Z][^A-Z]*', text))",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the product of numbers is even or not.\n    ### Response:\n    def is_Product_Even(arr,n): for i in range(0,n): if ((arr[i] & 1) == 0): return True return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to shift first element to the end of given list.\n    ### Response:\n    def move_last(num_list): a = [num_list[0] for i in range(num_list.count(num_list[0]))] x = [ i for i in num_list if i != num_list[0]] x.extend(a) return (x)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to extract the maximum numeric value from a string by using regex.\n    ### Response:\n    import re def extract_max(input): numbers = re.findall('\\d+',input) numbers = map(int,numbers) return max(numbers)",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the smallest prime divisor of a number.\n    ### Response:\n    def smallest_Divisor(n): if (n % 2 == 0): return 2; i = 3; while (i*i <= n): if (n % i == 0): return i; i += 2; return n;',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find minimum adjacent swaps required to sort binary array.\n    ### Response:\n    def find_Min_Swaps(arr,n) : noOfZeroes = [0] * n count = 0 noOfZeroes[n - 1] = 1 - arr[n - 1] for i in range(n-2,-1,-1) : noOfZeroes[i] = noOfZeroes[i + 1] if (arr[i] == 0) : noOfZeroes[i] = noOfZeroes[i] + 1 for i in range(0,n) : if (arr[i] == 1) : count = count + noOfZeroes[i] return count',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to copy a list from a singleton tuple.\n    ### Response:\n    def lcopy(xs): return xs[:]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the equilibrium index of the given array.\n    ### Response:\n    def equilibrium_index(arr): total_sum = sum(arr) left_sum=0 for i, num in enumerate(arr): total_sum -= num if left_sum == total_sum: return i left_sum += num return -1',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find sum of odd factors of a number.\n    ### Response:\n    import math def sum_of_odd_Factors(n): res = 1 while n % 2 == 0: n = n // 2 for i in range(3,int(math.sqrt(n) + 1)): count = 0 curr_sum = 1 curr_term = 1 while n % i == 0: count+=1 n = n // i curr_term *= i curr_sum += curr_term res *= curr_sum if n >= 2: res *= (1 + n) return res',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to calculate the sum of the positive numbers of a given list of numbers using lambda function.\n    ### Response:\n    def sum_positivenum(nums): sum_positivenum = list(filter(lambda nums:nums>0,nums)) return sum(sum_positivenum)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the maximum of similar indices in two lists of tuples.\n    ### Response:\n    def max_similar_indices(test_list1, test_list2): res = [(max(x[0], y[0]), max(x[1], y[1])) for x, y in zip(test_list1, test_list2)] return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to interchange first and last elements in a given list.\n    ### Response:\n    def swap_List(newList): size = len(newList) temp = newList[0] newList[0] = newList[size - 1] newList[size - 1] = temp return newList',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find numbers within a given range where every number is divisible by every digit it contains.\n    ### Response:\n    def divisible_by_digits(startnum, endnum): return [n for n in range(startnum, endnum+1) \\ if not any(map(lambda x: int(x) == 0 or n%int(x) != 0, str(n)))]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the smallest missing number from the given array.\n    ### Response:\n    def find_First_Missing(array,start,end): if (start > end): return end + 1 if (start != array[start]): return start; mid = int((start + end) / 2) if (array[mid] == mid): return find_First_Missing(array,mid+1,end) return find_First_Missing(array,start,mid)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to combine two given sorted lists using heapq module.\n    ### Response:\n    from heapq import merge def combine_lists(num1,num2): combine_lists=list(merge(num1, num2)) return combine_lists',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the roots of a quadratic equation are numerically equal but opposite in sign or not.\n    ### Response:\n    def Check_Solution(a,b,c): if b == 0: return ("Yes") else: return ("No")',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the two given strings are isomorphic to each other or not.\n    ### Response:\n    def is_Isomorphic(str1,str2): dict_str1 = {} dict_str2 = {} for i, value in enumerate(str1): dict_str1[value] = dict_str1.get(value,[]) + [i] for j, value in enumerate(str2): dict_str2[value] = dict_str2.get(value,[]) + [j] if sorted(dict_str1.values()) == sorted(dict_str2.values()): return True else: return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to print n-times a list using map function.\n    ### Response:\n    def ntimes_list(nums,n): result = map(lambda x:n*x, nums) return list(result)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to count lower case letters in a given string.\n    ### Response:\n    def lower_ctr(str): lower_ctr= 0 for i in range(len(str)): if str[i] >= 'a' and str[i] <= 'z': lower_ctr += 1 return lower_ctr",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if a triangle of positive area is possible with the given angles.\n    ### Response:\n    def is_triangleexists(a,b,c): if(a != 0 and b != 0 and c != 0 and (a + b + c)== 180): if((a + b)>= c or (b + c)>= a or (a + c)>= b): return True else: return False else: return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to count the number of rotations required to generate a sorted array.\n    ### Response:\n    def count_Rotation(arr,n): for i in range (1,n): if (arr[i] < arr[i - 1]): return i return 0',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the first digit in factorial of a given number.\n    ### Response:\n    import math def first_Digit(n) : fact = 1 for i in range(2,n + 1) : fact = fact * i while (fact % 10 == 0) : fact = int(fact / 10) while (fact >= 10) : fact = int(fact / 10) return math.floor(fact)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to get the difference between two lists.\n    ### Response:\n    def Diff(li1,li2): return (list(list(set(li1)-set(li2)) + list(set(li2)-set(li1))))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the largest subset where each pair is divisible.\n    ### Response:\n    def largest_subset(a, n): dp = [0 for i in range(n)] dp[n - 1] = 1; for i in range(n - 2, -1, -1): mxm = 0; for j in range(i + 1, n): if a[j] % a[i] == 0 or a[i] % a[j] == 0: mxm = max(mxm, dp[j]) dp[i] = 1 + mxm return max(dp)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to calculate the sum of series 1 +2 +3 + .+n .\n    ### Response:\n    import math def sum_series(number): total = 0 total = math.pow((number * (number + 1)) /2, 2) return total',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the product of first even and odd number of a given list.\n    ### Response:\n    def mul_even_odd(list1): first_even = next((el for el in list1 if el%2==0),-1) first_odd = next((el for el in list1 if el%2!=0),-1) return (first_even*first_odd)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to remove spaces from a given string.\n    ### Response:\n    def remove_spaces(str1): str1 = str1.replace(' ','') return str1",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if the given array represents min heap or not.\n    ### Response:\n    def check_min_heap(arr, i): if 2 * i + 2 > len(arr): return True left_child = (arr[i] <= arr[2 * i + 1]) and check_min_heap(arr, 2 * i + 1) right_child = (2 * i + 2 == len(arr)) or (arr[i] <= arr[2 * i + 2] and check_min_heap(arr, 2 * i + 2)) return left_child and right_child',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to compute maximum product of three numbers of a given array of integers using heap queue algorithm.\n    ### Response:\n    def maximum_product(nums): import heapq a, b = heapq.nlargest(3, nums), heapq.nsmallest(2, nums) return max(a[0] * a[1] * a[2], a[0] * b[0] * b[1])',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the combinations of sums with tuples in the given tuple list.\n    ### Response:\n    from itertools import combinations def find_combinations(test_list): res = [(b1 + a1, b2 + a2) for (a1, a2), (b1, b2) in combinations(test_list, 2)] return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether an array can be sorted or not by picking only the corner elements.\n    ### Response:\n    def check(arr,n): g = 0 for i in range(1,n): if (arr[i] - arr[i - 1] > 0 and g == 1): return False if (arr[i] - arr[i] < 0): g = 1 return True',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the list in a list of lists whose sum of elements is the highest.\n    ### Response:\n    def max_sum_list(lists): return max(lists, key=sum)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to reverse words in a given string.\n    ### Response:\n    def reverse_words(s): return ' '.join(reversed(s.split()))",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to round up a number to specific digits.\n    ### Response:\n    import math def round_up(a, digits): n = 10**-digits return round(math.ceil(a / n) * n, digits)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to separate and print the numbers and their position of a given string.\n    ### Response:\n    import re def num_position(text): for m in re.finditer("\\d+", text): return m.start()',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to convert the given string of float type into tuple.\n    ### Response:\n    def float_to_tuple(test_str): res = tuple(map(float, test_str.split(', '))) return (res)",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if two lists of tuples are identical or not.\n    ### Response:\n    def check_identical(test_list1, test_list2): res = test_list1 == test_list2 return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find length of the subarray having maximum sum.\n    ### Response:\n    from sys import maxsize def max_sub_array_sum(a,size): max_so_far = -maxsize - 1 max_ending_here = 0 start = 0 end = 0 s = 0 for i in range(0,size): max_ending_here += a[i] if max_so_far < max_ending_here: max_so_far = max_ending_here start = s end = i if max_ending_here < 0: max_ending_here = 0 s = i+1 return (end - start + 1)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the longest common subsequence for the given three string sequence.\n    ### Response:\n    def lcs_of_three(X, Y, Z, m, n, o): L = [[[0 for i in range(o+1)] for j in range(n+1)] for k in range(m+1)] for i in range(m+1): for j in range(n+1): for k in range(o+1): if (i == 0 or j == 0 or k == 0): L[i][j][k] = 0 elif (X[i-1] == Y[j-1] and X[i-1] == Z[k-1]): L[i][j][k] = L[i-1][j-1][k-1] + 1 else: L[i][j][k] = max(max(L[i-1][j][k], L[i][j-1][k]), L[i][j][k-1]) return L[m][n][o]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the sum of fourth power of first n even natural numbers.\n    ### Response:\n    def even_Power_Sum(n): sum = 0; for i in range(1,n + 1): j = 2*i; sum = sum + (j*j*j*j); return sum;',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to exchange the position of every n-th value with (n+1)th value and (n+1)th value with n-th value in a given list.\n    ### Response:\n    from itertools import zip_longest, chain, tee def exchange_elements(lst): lst1, lst2 = tee(iter(lst), 2) return list(chain.from_iterable(zip_longest(lst[1::2], lst[::2])))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the sum of first even and odd number of a given list.\n    ### Response:\n    def sum_even_odd(list1): first_even = next((el for el in list1 if el%2==0),-1) first_odd = next((el for el in list1 if el%2!=0),-1) return (first_even+first_odd)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to sum a specific column of a list in a given list of lists.\n    ### Response:\n    def sum_column(list1, C): result = sum(row[C] for row in list1) return result',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the given strings are rotations of each other or not.\n    ### Response:\n    def are_Rotations(string1,string2): size1 = len(string1) size2 = len(string2) temp = '' if size1 != size2: return False temp = string1 + string1 if (temp.count(string2)> 0): return True else: return False",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to count the number of equal numbers from three given integers.\n    ### Response:\n    def test_three_equal(x,y,z): result= set([x,y,z]) if len(result)==3: return 0 else: return (4-len(result))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to remove negative numbers from a list.\n    ### Response:\n    def remove_negs(num_list): for item in num_list: if item < 0: num_list.remove(item) return num_list',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to convert a string to a list.\n    ### Response:\n    def Convert(string): li = list(string.split(" ")) return li',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to replace all spaces in the given string with character * list item * list item * list item * list item '%20'.\n    ### Response:\n    MAX=1000; def replace_spaces(string): string=string.strip() i=len(string) space_count=string.count(' ') new_length = i + space_count*2 if new_length > MAX: return -1 index = new_length-1 string=list(string) for f in range(i-2, new_length-2): string.append('0') for j in range(i-1, 0, -1): if string[j] == ' ': string[index] = '0' string[index-1] = '2' string[index-2] = '%' index=index-3 else: string[index] = string[j] index -= 1 return ''.join(string)",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the kth element in an array containing odd elements first and then even elements.\n    ### Response:\n    def get_Number(n, k): arr = [0] * n; i = 0; odd = 1; while (odd <= n): arr[i] = odd; i += 1; odd += 2; even = 2; while (even <= n): arr[i] = even; i += 1; even += 2; return arr[k - 1];',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to print the first n lucky numbers.\n    ### Response:\n    def lucky_num(n): List=range(-1,n*n+9,2) i=2 while List[i:]:List=sorted(set(List)-set(List[List[i]::List[i]]));i+=1 return List[1:n+1]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to concatenate the given two tuples to a nested tuple.\n    ### Response:\n    def concatenate_nested(test_tup1, test_tup2): res = test_tup1 + test_tup2 return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find numbers divisible by m or n from a list of numbers using lambda function.\n    ### Response:\n    def div_of_nums(nums,m,n): result = list(filter(lambda x: (x % m == 0 or x % n == 0), nums)) return result',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check for even parity of a given number.\n    ### Response:\n    def check_Even_Parity(x): parity = 0 while (x != 0): x = x & (x - 1) parity += 1 if (parity % 2 == 0): return True else: return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the product of it s kth index in the given tuples.\n    ### Response:\n    def get_product(val) : res = 1 for ele in val: res *= ele return res def find_k_product(test_list, K): res = get_product([sub[K] for sub in test_list]) return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to locate the right insertion point for a specified value in sorted order.\n    ### Response:\n    import bisect def right_insertion(a, x): i = bisect.bisect_right(a, x) return i',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function that matches a string that has an a followed by zero or more b's.\n    ### Response:\n    import re def text_match(text): patterns = 'ab*?' if re.search(patterns, text): return 'Found a match!' else: return('Not matched!')",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to sum elements in two lists.\n    ### Response:\n    def sum_list(lst1,lst2): res_list = [lst1[i] + lst2[i] for i in range(len(lst1))] return res_list',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find three closest elements from three sorted arrays.\n    ### Response:\n    import sys def find_closet(A, B, C, p, q, r): diff = sys.maxsize res_i = 0 res_j = 0 res_k = 0 i = 0 j = 0 k = 0 while(i < p and j < q and k < r): minimum = min(A[i], min(B[j], C[k])) maximum = max(A[i], max(B[j], C[k])); if maximum-minimum < diff: res_i = i res_j = j res_k = k diff = maximum - minimum; if diff == 0: break if A[i] == minimum: i = i+1 elif B[j] == minimum: j = j+1 else: k = k+1 return A[res_i],B[res_j],C[res_k]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to caluclate perimeter of a parallelogram.\n    ### Response:\n    def parallelogram_perimeter(b,h): perimeter=2*(b*h) return perimeter',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to count the number of unique lists within a list.\n    ### Response:\n    def unique_sublists(list1): result ={} for l in list1: result.setdefault(tuple(l), list()).append(1) for a, b in result.items(): result[a] = sum(b) return result',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to sum the length of the names of a given list of names after removing the names that start with a lowercase letter.\n    ### Response:\n    def sample_nam(sample_names): sample_names=list(filter(lambda el:el[0].isupper() and el[1:].islower(),sample_names)) return len(''.join(sample_names))",
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to remove an empty tuple from a list of tuples.\n    ### Response:\n    def remove_empty(tuple1): #L = [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), ('d')] tuple1 = [t for t in tuple1 if t] return tuple1",
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function that matches a string that has an 'a' followed by anything, ending in 'b' by using regex.\n    ### Response:\n    import re def text_match(text): patterns = 'a.*?b$' if re.search(patterns, text): return ('Found a match!') else: return ('Not matched!')",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the given number can be represented by sum of two squares or not.\n    ### Response:\n    def sum_Square(n) : i = 1 while i*i <= n : j = 1 while (j*j <= n) : if (i*i+j*j == n) : return True j = j+1 i = i+1 return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to multiply consecutive numbers of a given list.\n    ### Response:\n    def mul_consecutive_nums(nums): result = [b*a for a, b in zip(nums[:-1], nums[1:])] return result',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to abbreviate 'road' as 'rd.' in a given string.\n    ### Response:\n    import re def road_rd(street): return (re.sub('Road$', 'Rd.', street))",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the minimum number of swaps required to convert one binary string to another.\n    ### Response:\n    def min_Swaps(str1,str2) : count = 0 for i in range(len(str1)) : if str1[i] != str2[i] : count += 1 if count % 2 == 0 : return (count // 2) else : return ("Not Possible")',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the count of divisors is even or odd.\n    ### Response:\n    import math def count_Divisors(n) : count = 0 for i in range(1, (int)(math.sqrt(n)) + 2) : if (n % i == 0) : if( n // i == i) : count = count + 1 else : count = count + 2 if (count % 2 == 0) : return ("Even") else : return ("Odd")',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the type of triangle from the given sides.\n    ### Response:\n    def check_Type_Of_Triangle(a,b,c): sqa = pow(a,2) sqb = pow(b,2) sqc = pow(c,2) if (sqa == sqa + sqb or sqb == sqa + sqc or sqc == sqa + sqb): return ("Right-angled Triangle") elif (sqa > sqc + sqb or sqb > sqa + sqc or sqc > sqa + sqb): return ("Obtuse-angled Triangle") else: return ("Acute-angled Triangle")',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check whether the given ip address is valid or not using regex.\n    ### Response:\n    import re regex = \'\'\'^(25[0-5]|2[0-4][0-9]|[0-1]?[0-9][0-9]?)\\.( 25[0-5]|2[0-4][0-9]|[0-1]?[0-9][0-9]?)\\.( 25[0-5]|2[0-4][0-9]|[0-1]?[0-9][0-9]?)\\.( 25[0-5]|2[0-4][0-9]|[0-1]?[0-9][0-9]?)$\'\'\' def check_IP(Ip): if(re.search(regex, Ip)): return ("Valid IP address") else: return ("Invalid IP address")',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check for a number at the end of a string.\n    ### Response:\n    import re def end_num(string): text = re.compile(r".*[0-9]$") if text.match(string): return True else: return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to extract all the adjacent coordinates of the given coordinate tuple.\n    ### Response:\n    def adjac(ele, sub = []): if not ele: yield sub else: yield from [idx for j in range(ele[0] - 1, ele[0] + 2) for idx in adjac(ele[1:], sub + [j])] def get_coordinates(test_tup): res = list(adjac(test_tup)) return (res)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to split the given string at uppercase letters by using regex.\n    ### Response:\n    import re def split_list(text): return (re.findall('[A-Z][^A-Z]*', text))",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the second smallest number in a list.\n    ### Response:\n    def second_smallest(numbers): if (len(numbers)<2): return if ((len(numbers)==2) and (numbers[0] == numbers[1]) ): return dup_items = set() uniq_items = [] for x in numbers: if x not in dup_items: uniq_items.append(x) dup_items.add(x) uniq_items.sort() return uniq_items[1]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the maximum value in record list as tuple attribute in the given tuple list.\n    ### Response:\n    def maximum_value(test_list): res = [(key, max(lst)) for key, lst in test_list] return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the average of a list.\n    ### Response:\n    def Average(lst): return sum(lst) / len(lst)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if a nested list is a subset of another nested list.\n    ### Response:\n    def check_subset(list1,list2): return all(map(list1.__contains__,list2))',
# ...
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check if each element of second tuple is smaller than its corresponding index in first tuple.\n    ### Response:\n    def check_smaller(test_tup1, test_tup2): res = all(x > y for x, y in zip(test_tup1, test_tup2)) return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to move all zeroes to the end of the given list.\n    ### Response:\n    def move_zero(num_list): a = [0 for i in range(num_list.count(0))] x = [ i for i in num_list if i != 0] x.extend(a) return (x)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to remove consecutive duplicates of a given list.\n    ### Response:\n    from itertools import groupby def consecutive_duplicates(nums): return [key for key, group in groupby(nums)]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to calculate the height of the given binary tree.\n    ### Response:\n    class Node: def __init__(self, data): self.data = data self.left = None self.right = None def max_height(node): if node is None: return 0 ; else : left_height = max_height(node.left) right_height = max_height(node.right) if (left_height > right_height): return left_height+1 else: return right_height+1',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find whether an array is subset of another array.\n    ### Response:\n    def is_subset(arr1, m, arr2, n): hashset = set() for i in range(0, m): hashset.add(arr1[i]) for i in range(0, n): if arr2[i] in hashset: continue else: return False return True',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the given two numbers have same number of digits or not.\n    ### Response:\n    def same_Length(A,B): while (A > 0 and B > 0): A = A / 10; B = B / 10; if (A == 0 and B == 0): return True; return False;',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find the length of the last word in a given string.\n    ### Response:\n    def length_Of_Last_Word(a): l = 0 x = a.strip() for i in range(len(x)): if x[i] == " ": l = 0 else: l += 1 return l',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find length of the string.\n    ### Response:\n    def string_length(str1): count = 0 for char in str1: count += 1 return count',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to reverse an array upto a given position.\n    ### Response:\n    def reverse_Array_Upto_K(input, k): return (input[k-1::-1] + input[k:])',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to sort the given tuple list basis the total digits in tuple.\n    ### Response:\n    def count_digs(tup): return sum([len(str(ele)) for ele in tup ]) def sort_list(test_list): test_list.sort(key = count_digs) return (str(test_list))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to caluclate arc length of an angle.\n    ### Response:\n    def arc_length(d,a): pi=22/7 if a >= 360: return None arclength = (pi*d) * (a/360) return arclength',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to count coin change.\n    ### Response:\n    def coin_change(S, m, n): table = [[0 for x in range(m)] for x in range(n+1)] for i in range(m): table[0][i] = 1 for i in range(1, n+1): for j in range(m): x = table[i - S[j]][j] if i-S[j] >= 0 else 0 y = table[i][j-1] if j >= 1 else 0 table[i][j] = x + y return table[n][m-1]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the item with maximum occurrences in a given list.\n    ### Response:\n    def max_occurrences(list1): max_val = 0 result = list1[0] for i in list1: occu = list1.count(i) if occu > max_val: max_val = occu result = i return result',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to find number of solutions in quadratic equation.\n    ### Response:\n    def Check_Solution(a,b,c) : if ((b*b) - (4*a*c)) > 0 : return ("2 solutions") elif ((b*b) - (4*a*c)) == 0 : return ("1 solution") else : return ("No solutions")',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to convert the given string to upper case.\n    ### Response:\n    def is_upper(string): return (string.upper())',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to solve the fibonacci sequence using recursion.\n    ### Response:\n    def fibonacci(n): if n == 1 or n == 2: return 1 else: return (fibonacci(n - 1) + (fibonacci(n - 2)))',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to perfom the modulo of tuple elements in the given two tuples.\n    ### Response:\n    def tuple_modulo(test_tup1, test_tup2): res = tuple(ele1 % ele2 for ele1, ele2 in zip(test_tup1, test_tup2)) return (res)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the sequences of one upper case letter followed by lower case letters.\n    ### Response:\n    import re def text_uppercase_lowercase(text): patterns = '[A-Z]+[a-z]+$' if re.search(patterns, text): return 'Found a match!' else: return ('Not matched!')",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to access the initial and last data of the given tuple record.\n    ### Response:\n    def front_and_rear(test_tup): res = (test_tup[0], test_tup[-1]) return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to calculate the geometric sum of n-1.\n    ### Response:\n    def geometric_sum(n): if n < 0: return 0 else: return 1 / (pow(2, n)) + geometric_sum(n - 1)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to remove the nested record from the given tuple.\n    ### Response:\n    def remove_nested(test_tup): res = tuple() for count, ele in enumerate(test_tup): if not isinstance(ele, tuple): res = res + (ele, ) return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to substract the elements of the given nested tuples.\n    ### Response:\n    def substract_elements(test_tup1, test_tup2): res = tuple(tuple(a - b for a, b in zip(tup1, tup2)) for tup1, tup2 in zip(test_tup1, test_tup2)) return (res)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check for the number of jumps required of given length to reach a point of form (d, 0) from origin in a 2d plane.\n    ### Response:\n    def min_Jumps(a, b, d): temp = a a = min(a, b) b = max(temp, b) if (d >= b): return (d + b - 1) / b if (d == 0): return 0 if (d == a): return 1 else: return 2',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the smallest multiple of the first n numbers.\n    ### Response:\n    def smallest_multiple(n): if (n<=2): return n i = n * 2 factors = [number for number in range(n, 1, -1) if number * 2 > n] while True: for a in factors: if i % a != 0: i += n break if (a == factors[-1] and i % a == 0): return i',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to count the number of inversions in the given array.\n    ### Response:\n    def get_inv_count(arr, n): inv_count = 0 for i in range(n): for j in range(i + 1, n): if (arr[i] > arr[j]): inv_count += 1 return inv_count',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the product of digits of a number at even and odd places is equal or not.\n    ### Response:\n    def product_Equal(n): if n < 10: return False prodOdd = 1; prodEven = 1 while n > 0: digit = n % 10 prodOdd *= digit n = n//10 if n == 0: break; digit = n % 10 prodEven *= digit n = n//10 if prodOdd == prodEven: return True return False',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write function to find the sum of all items in the given dictionary.\n    ### Response:\n    def return_sum(dict): sum = 0 for i in dict.values(): sum = sum + i return sum',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to push all values into a heap and then pop off the smallest values one at a time.\n    ### Response:\n    import heapq as hq def heap_sort(iterable): h = [] for value in iterable: hq.heappush(h, value) return [hq.heappop(h) for i in range(len(h))]',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the given number is odd or not using bitwise operator.\n    ### Response:\n    def is_odd(n) : if (n^1 == n-1) : return True; else : return False;',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to rearrange positive and negative numbers in a given array using lambda function.\n    ### Response:\n    def rearrange_numbs(array_nums): result = sorted(array_nums, key = lambda i: 0 if i == 0 else -1 / i) return result',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check if roots of a quadratic equation are reciprocal of each other or not.\n    ### Response:\n    def Check_Solution(a,b,c): if (a == c): return ("Yes"); else: return ("No");',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to find the nth delannoy number.\n    ### Response:\n    def dealnnoy_num(n, m): if (m == 0 or n == 0) : return 1 return dealnnoy_num(m - 1, n) + dealnnoy_num(m - 1, n - 1) + dealnnoy_num(m, n - 1)',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to convert rgb color to hsv color.\n    ### Response:\n    def rgb_to_hsv(r, g, b): r, g, b = r/255.0, g/255.0, b/255.0 mx = max(r, g, b) mn = min(r, g, b) df = mx-mn if mx == mn: h = 0 elif mx == r: h = (60 * ((g-b)/df) + 360) % 360 elif mx == g: h = (60 * ((b-r)/df) + 120) % 360 elif mx == b: h = (60 * ((r-g)/df) + 240) % 360 if mx == 0: s = 0 else: s = (df/mx)*100 v = mx*100 return h, s, v',
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a python function to check whether the given two arrays are equal or not.\n    ### Response:\n    def are_Equal(arr1,arr2,n,m): if (n != m): return False arr1.sort() arr2.sort() for i in range(0,n - 1): if (arr1[i] != arr2[i]): return False return True',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to search a literals string in a string and also find the location within the original string where the pattern occurs by using regex.\n    ### Response:\n    import re pattern = 'fox' text = 'The quick brown fox jumps over the lazy dog.' def find_literals(text, pattern): match = re.search(pattern, text) s = match.start() e = match.end() return (match.re.pattern, s, e)",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to check whether the given key is present in the dictionary or not.\n    ### Response:\n    def is_key_present(d,x): if x in d: return True else: return False',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to count those characters which have vowels as their neighbors in the given string.\n    ### Response:\n    def count_vowels(test_str): res = 0 vow_list = ['a', 'e', 'i', 'o', 'u'] for idx in range(1, len(test_str) - 1): if test_str[idx] not in vow_list and (test_str[idx - 1] in vow_list or test_str[idx + 1] in vow_list): res += 1 if test_str[0] not in vow_list and test_str[1] in vow_list: res += 1 if test_str[-1] not in vow_list and test_str[-2] in vow_list: res += 1 return (res)",
#  'Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to convert the given tuple to a key-value dictionary using adjacent elements.\n    ### Response:\n    def tuple_to_dict(test_tup): res = dict(test_tup[idx : idx + 2] for idx in range(0, len(test_tup), 2)) return (res)',
#  "Below is an instruction that describes a python code writing task. Write a response that appropriately passes the test cases.\n    ### Instruction: Write a function to convert a roman numeral to an integer.\n    ### Response:\n    def roman_to_int(s): rom_val = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000} int_val = 0 for i in range(len(s)): if i > 0 and rom_val[s[i]] > rom_val[s[i - 1]]: int_val += rom_val[s[i]] - 2 * rom_val[s[i - 1]] else: int_val += rom_val[s[i]] return int_val"]

# %% [markdown]
# **Preparing the model for QLoRA :**

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
model = prepare_model_for_kbit_training(model)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %% [markdown]
#  **Set Up LoRA :**
# Now, to start my fine-tuning, i have to apply some preprocessing to the model to prepare it for training. Let's set up our LoRA layers.

# %%
lora_config = LoraConfig(
    r=16,                                                       # The rank of the LoRA matrices A, B
    lora_alpha=64,                                              # Scales the product AB
   target_modules=[ "Wqkv",
        "fc1",
        "fc2"],                                                 # Will apply LoRA to attention matrices
    lora_dropout=0.05,                                          # Dropout to help lessen overfitting
    bias="none",                                                # Don't train the bias parameter
    task_type="CAUSAL_LM"
)

#Get model with unfrozen LoRA layers

model = get_peft_model(model, lora_config)
print_trainable_parameters(model)
# Out:
# trainable params: 13107200 || all params: 1534499840 || trainable%: 0.8541675703270194

# %% [markdown]
# Here I define the LoRA config.
#
# r is the rank of the low-rank matrix used in the adapters, which thus controls the number of parameters trained. A higher rank will allow for more expressivity, but there is a compute tradeoff.
#
# alpha is the scaling factor for the learned weights. The weight matrix is scaled by alpha/r, and thus a higher value for alpha assigns more weight to the LoRA activations.
#
# The values used in the QLoRA paper were r=64 and lora_alpha=16, and these are said to generalize well, but i will use r=16 and lora_alpha=64 so that we have more emphasis on the new fine-tuned data while also reducing computational complexity.

# %% [markdown]
# Training Arguments

# %%
from transformers import TrainingArguments

project = "finetune2"
base_model_name = "llm2"
run_name = base_model_name + "-" + project
output_dir = "./" + run_name

training_arguments = TrainingArguments(
    fp16=True,                           # Training computations in 16 bits
    # batch-related
    per_device_train_batch_size=1,       # Batch Size
    gradient_accumulation_steps=4,       # Batch Size (Mathematically)
    # optimizer-related
    optim="paged_adamw_32bit",           # Variant of AdamW designed to be more efficient on 32-bit GPUs
    learning_rate=1e-4,                  # Learning Rate
    warmup_ratio=0.05,                   # After 5% of the data, learning rate has linearly  from 0 to 1e-4
    lr_scheduler_type="linear",          # Adjust learning rate sinusoidally
    max_grad_norm=0.3,                   # Clip gradients if less than 0.3 (prevent gradient explosion)
    # epochs and saving
    num_train_epochs=2,                  # Number of Epochs
    save_strategy="epoch",               # Save after each epoch
    output_dir=output_dir,        # Where to save the model
    # validation
    evaluation_strategy="steps",         # For the next argument
    eval_steps=0.2,                      # Evaluate after 20% of training steps
    # logging-related
    logging_steps=1,                     # Number of update steps between two logs
    group_by_length=True,                # Minimize padding by grouping sentences of similar length
    seed=42,                             # For consistent results
    weight_decay=0.01
)
model.gradient_checkpointing_enable()    # Store less activations and recompute later
model.config.use_cache = False           # Disable using attention output cache. Should be enabled in inference.
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# **Fine tuned Model A on training dataset :**

# %%
from trl import SFTTrainer, DataCollatorForCompletionOnlyLM

response_template = "### Response:"
collator = DataCollatorForCompletionOnlyLM(response_template, tokenizer=tokenizer)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_data.rename_columns({"prompt": "text"}),  # Rename "prompt" to "text"
    eval_dataset=validation_data.rename_columns({"prompt": "text"}),
    peft_config=lora_config,
    args=training_arguments,
    data_collator=collator
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer.train()
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: soureesh1211 (soureesh1211-university-of-illinois-chicago) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/content/wandb/run-20250227_004345-3fuqlnr2</code>
# Syncing run <strong><a href='https://wandb.ai/soureesh1211-university-of-illinois-chicago/huggingface/runs/3fuqlnr2' target="_blank">./llm2-finetune2</a></strong> to <a href='https://wandb.ai/soureesh1211-university-of-illinois-chicago/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/soureesh1211-university-of-illinois-chicago/huggingface' target="_blank">https://wandb.ai/soureesh1211-university-of-illinois-chicago/huggingface</a>
#  View run at <a href='https://wandb.ai/soureesh1211-university-of-illinois-chicago/huggingface/runs/3fuqlnr2' target="_blank">https://wandb.ai/soureesh1211-university-of-illinois-chicago/huggingface/runs/3fuqlnr2</a>
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 08:15, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>36</td>
#       <td>0.609300</td>
#       <td>0.741288</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.804300</td>
#       <td>0.678130</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.919400</td>
#       <td>0.674724</td>
#     </tr>
#     <tr>
#       <td>144</td>
#       <td>0.705700</td>
#       <td>0.657462</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.470600</td>
#       <td>0.680320</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# TrainOutput(global_step=180, training_loss=0.753661371436384, metrics={'train_runtime': 502.547, 'train_samples_per_second': 1.433, 'train_steps_per_second': 0.358, 'total_flos': 1223677417697280.0, 'train_loss': 0.753661371436384})

# %%
peft_model_path = "/content/drive/MyDrive/ColabResults/fine-tuned-modelA"
trainer.model.save_pretrained(peft_model_path)
tokenizer.save_pretrained(peft_model_path)
# Out:
# ('/content/drive/MyDrive/ColabResults/fine-tuned-modelA/tokenizer_config.json',
#  '/content/drive/MyDrive/ColabResults/fine-tuned-modelA/special_tokens_map.json',
#  '/content/drive/MyDrive/ColabResults/fine-tuned-modelA/vocab.json',
#  '/content/drive/MyDrive/ColabResults/fine-tuned-modelA/merges.txt',
#  '/content/drive/MyDrive/ColabResults/fine-tuned-modelA/added_tokens.json',
#  '/content/drive/MyDrive/ColabResults/fine-tuned-modelA/tokenizer.json')

# %%
from peft import AutoPeftModelForCausalLM
from transformers import AutoTokenizer

tuned_modelA = AutoPeftModelForCausalLM.from_pretrained(peft_model_path, low_cpu_mem_usage=True, torch_dtype=torch.float16, load_in_4bit=True)
tokenizerA = AutoTokenizer.from_pretrained(peft_model_path)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
test_input = "Write a Python function to compute the factorial of a number."
response = generate_tuned_model(tuned_modelA, tokenizerA, test_input)
print(f"Fine-Tuned Model Response:\n{response}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Fine-Tuned Model Response:
# def factorial(n): if (n == 1): return 1 else: return n * factorial(n - 1) n = int(input("Enter a number: ")) if (n < 0): return -1 else: return factorial(n) n = int(input("Enter a number: ")) if (n < 0): return -1 else: return factorial(n) n = int(input("Enter a number: ")) if (n < 0): return -1 else: return factorial(n) n = int(input("Enter a number: ")) if (n
